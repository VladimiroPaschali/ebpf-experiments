# %%
import matplotlib.pyplot as plt

# %%
# Sample list of values
values = [659181927,369112500,3548,1733,707,382,311,228,441,1,1,2,0,0,1,2,5]

bins = list(range(len(values)))

# Plot the histogram
plt.bar(bins, values, edgecolor='black')

# Add titles and labels
plt.xlabel('run_cnt diff')
plt.ylabel('Count')

# Show the plot
plt.show()
